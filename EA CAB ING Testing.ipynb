# %%
from vector_db import setup_vector_db

# %%
# Simple in-memory setup
db = setup_vector_db()

# Persistent with embeddings
db = setup_vector_db(
    collection_name="my_docs",
    persist_directory="./chroma_db",
    embedding_provider="sentence_transformers"
)
